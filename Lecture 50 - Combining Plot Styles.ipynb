# %%
import numpy as np
import pandas as pd
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = randn(100)

# %%
sns.distplot(dataset, bins=25)

# %%
sns.distplot(dataset, bins=25, rug=True, hist=False)

# %%
sns.distplot(dataset, bins=25,
            kde_kws={'color':'indianred', 'label': 'KDE Plot'},
            hist_kws={'color':'blue','label': 'HIST'})

# %%
from pandas import Series

# %%
ser1 = Series(dataset, name='My_dataset')
ser1
# Out:
# 0     0.716155
# 1    -1.039626
# 2     0.023316
# 3    -0.098372
# 4    -1.427260
# 5     0.989690
# 6     0.749368
# 7     0.455526
# 8     0.507668
# 9     1.596015
# 10   -1.109465
# 11   -1.420802
# 12   -0.203393
# 13    0.118860
# 14   -0.654748
# 15   -2.093983
# 16    0.990753
# 17   -1.025463
# 18    1.308965
# 19    0.712623
# 20    0.328918
# 21   -0.126117
# 22   -0.762690
# 23   -1.587702
# 24    1.198968
# 25   -2.405886
# 26    0.498823
# 27    1.233545
# 28    1.203906
# 29    0.867385
#         ...
# 70    1.975933
# 71    0.421850
# 72    0.604150
# 73   -0.943760
# 74   -1.540665
# 75   -1.234044
# 76    1.390751
# 77   -0.343798
# 78   -0.117458
# 79   -0.444621
# 80   -1.924110
# 81    1.352621
# 82   -1.373987
# 83    0.704487
# 84   -0.216324
# 85   -1.604687
# 86   -0.203325
# 87   -0.708231
# 88   -2.067178
# 89    0.285517
# 90   -1.399708
# 91    0.308639
# 92    1.915049
# 93    0.011972
# 94   -0.503523
# 95   -0.224734
# 96    0.645208
# 97    0.009482
# 98   -0.615990
# 99   -1.316535
# Name: My_dataset, Length: 100, dtype: float64

# %%
sns.distplot(ser1, bins=25)
